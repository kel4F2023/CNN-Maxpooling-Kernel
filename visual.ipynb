# %% [markdown]
# # Kernel Perf Result Notebook

# %%
# importing libraries
import matplotlib.pyplot as plt
import pandas as pd

# %%
# visualizing performance for mid-report implementation

df = pd.read_csv('data/mid-data.tsv', delimiter='\t')
df.columns = ['p', 'z', 'k', 'oflops', 'blops', 'correct']
df['k'].astype(int)
df['p'].astype(int)
df['z'].astype(int)
df['oflops'].astype(float)
df['blops'].astype(float)
df['correct'].astype(int)

# plot k against oflops and blops in one graph
oflops_avg = df.groupby('k')['oflops'].mean()
blops_avg = df.groupby('k')['blops'].mean()

plt.figure()
plt.axhline(y=8, color='r', linestyle='-', label='Max perf')
plt.plot(df['k'].unique(), oflops_avg, label='kernel')
plt.plot(df['k'].unique(), blops_avg, label='baseline')
plt.xticks(df['k'].unique()[1::2])
plt.legend()
plt.xlabel('k')
plt.ylabel('flops')
plt.title('layer size against flops')
plt.show()

# %%
# visualizing performance for mid-report implementation

df = pd.read_csv('data/final-data.tsv', delimiter='\t')
df.columns = ['p', 'z', 'k', 'oflops', 'blops', 'correct']
df['k'].astype(int)
df['p'].astype(int)
df['z'].astype(int)
df['oflops'].astype(float)
df['blops'].astype(float)
df['correct'].astype(int)

# plot k against oflops and blops in one graph
oflops_avg = df.groupby('k')['oflops'].mean()
blops_avg = df.groupby('k')['blops'].mean()

plt.clf()
plt.figure()
plt.axhline(y=8, color='r', linestyle='-', label='Max perf')
plt.plot(df['k'].unique(), oflops_avg, label='kernel')
plt.plot(df['k'].unique(), blops_avg, label='baseline')
plt.xticks(df['k'].unique()[1::2])
plt.legend()
plt.xlabel('k')
plt.ylabel('flops')
plt.title('layer size against flops')
plt.show()
